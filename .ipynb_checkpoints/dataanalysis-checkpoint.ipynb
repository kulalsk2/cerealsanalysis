# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
Df = pd.read_csv('cereal.csv')

# %%
Df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
Df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
names = list(Df.head(10)['name'])
carbo = list(Df.head(10)['carbo'])
plt.figure(figsize=(15, 10))
sns.barplot(names, carbo)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.regplot(Df['fiber'], Df['rating'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fiber', ylabel='rating'>

# %%
sns.regplot(Df['fat'], Df['rating'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fat', ylabel='rating'>

# %%
Df.groupby(['calories', 'sodium']).mean()
# Out:
#                   protein       fat  fiber      carbo     sugars      potass  \
# calories sodium
# 50       0       1.500000  0.000000   0.50  11.500000   0.000000   32.500000
#          140     4.000000  0.000000  14.00   8.000000   0.000000  330.000000
# 70       130     4.000000  1.000000  10.00   5.000000   6.000000  280.000000
#          260     4.000000  1.000000   9.00   7.000000   5.000000  320.000000
# 80       0       2.000000  0.000000   3.00  16.000000   0.000000   95.000000
# 90       0       2.666667  0.000000   3.00  18.000000   2.000000  123.333333
#          15      2.000000  0.000000   3.00  15.000000   5.000000   90.000000
#          170     3.000000  0.000000   3.00  18.000000   2.000000   90.000000
#          200     2.000000  1.000000   4.00  15.000000   6.000000  125.000000
#          210     3.000000  0.000000   5.00  13.000000   5.000000  190.000000
# 100      0       4.000000  1.000000   1.90   9.666667   3.000000  101.666667
# ...

# %%
Df.drop(['calories'],axis=1)
# Out:
#                          name mfr type  protein  fat  sodium  fiber  carbo  \
# 0                   100% Bran   N    C        4    1     130   10.0    5.0
# 1           100% Natural Bran   Q    C        3    5      15    2.0    8.0
# 2                    All-Bran   K    C        4    1     260    9.0    7.0
# 3   All-Bran with Extra Fiber   K    C        4    0     140   14.0    8.0
# 4              Almond Delight   R    C        2    2     200    1.0   14.0
# ..                        ...  ..  ...      ...  ...     ...    ...    ...
# 72                    Triples   G    C        2    1     250    0.0   21.0
# 73                       Trix   G    C        1    1     140    0.0   13.0
# 74                 Wheat Chex   R    C        3    1     230    3.0   17.0
# 75                   Wheaties   G    C        3    1     200    3.0   17.0
# 76        Wheaties Honey Gold   G    C        2    1     200    1.0   16.0
#
#     sugars  potass  vitamins  shelf  weight  cups     rating
# ...

# %%
plt.style.use('ggplot')

# %%
Df['calories'].hist()
# Out:
# <AxesSubplot:>

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB
